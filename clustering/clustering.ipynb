# %%
import os
from os.path import join
from google.colab import drive

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
drive.mount("/content/drive/")
directory="/content/drive/MyDrive/data"
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
files = [f for f in os.listdir(directory) if os.path.isfile(join(directory, f))]
files
# Out:
# ['R1400.xlsx',
#  'U1400.xlsx',
#  'R99.xlsx',
#  'U99.xlsx',
#  'R1401.xlsx',
#  'U1401.xlsx',
#  'R98.xlsx',
#  'U98.xlsx']

# %%
all_files = {}

for file_name in files:
    file_path = join(directory, file_name)
    with pd.ExcelFile(file_path) as excel_file:
        sheets = {sheet: pd.read_excel(excel_file, sheet) for sheet in excel_file.sheet_names}
    all_files[file_name.split('.')[0]] = sheets

# %%
for file_name, sheets in all_files.items():
    print(f"File: {file_name}")
    for sheet_name, data in sheets.items():
        print(f"  Sheet: {sheet_name}, Data shape: {data.shape}")
# Out:
# File: R1400
#   Sheet: R1400Data, Data shape: (18370, 18)
#   Sheet: R1400P1, Data shape: (62972, 10)
#   Sheet: R1400P2, Data shape: (19452, 45)
#   Sheet: R1400P3S01, Data shape: (509426, 7)
#   Sheet: R1400P3S02, Data shape: (3621, 7)
#   Sheet: R1400P3S03, Data shape: (26019, 4)
#   Sheet: R1400P3S04, Data shape: (69396, 5)
#   Sheet: R1400P3S05, Data shape: (87768, 4)
#   Sheet: R1400P3S06, Data shape: (29465, 4)
#   Sheet: R1400P3S07, Data shape: (32866, 4)
#   Sheet: R1400P3S08, Data shape: (34928, 4)
#   Sheet: R1400P3S09, Data shape: (9523, 4)
#   Sheet: R1400P3S10, Data shape: (0, 4)
#   Sheet: R1400P3S11, Data shape: (9206, 4)
#   Sheet: R1400P3S12, Data shape: (66456, 4)
#   Sheet: R1400P3S13, Data shape: (180585, 3)
#   Sheet: R1400P3S14, Data shape: (4014, 4)
#   Sheet: R1400P4S01, Data shape: (10731, 19)
#   Sheet: R1400P4S02, Data shape: (12194, 19)
#   Sheet: R1400P4S03, Data shape: (25097, 11)
#   Sheet: R1400P4S04, Data shape: (32053, 8)
# File: U1400
#   Sheet: U1400Data, Data shape: (19618, 18)
#   Sheet: R1400P1, Data shape: (65942, 10)
#   Sheet: R1400P2, Data shape: (21516, 45)
#   Sheet: U1400P3S01, Data shape: (617707, 7)
#   Sheet: U1400P3S02, Data shape: (3207, 7)
#   Sheet: U1400P3S03, Data shape: (30896, 4)
#   Sheet: U1400P3S04, Data shape: (85990, 5)
#   Sheet: U1400P3S05, Data shape: (96497, 4)
#   Sheet: U1400P3S06, Data shape: (34081, 4)
#   Sheet: U1400P3S07, Data shape: (40175, 4)
#   Sheet: U1400P3S08, Data shape: (43990, 4)
#   Sheet: U1400P3S09, Data shape: (10918, 4)
#   Sheet: U1400P3S10, Data shape: (0, 4)
#   Sheet: U1400P3S11, Data shape: (14931, 4)
#   Sheet: U1400P3S12, Data shape: (80370, 4)
#   Sheet: U1400P3S13, Data shape: (220419, 3)
#   Sheet: U1400P3S14, Data shape: (2529, 4)
#   Sheet: U1400P4S01, Data shape: (12399, 19)
#   Sheet: U1400P4S02, Data shape: (6376, 19)
#   Sheet: U1400P4S03, Data shape: (24345, 11)
#   Sheet: U1400P4S04, Data shape: (32054, 8)
# File: R99
#   Sheet: R99Data, Data shape: (18251, 19)
#   Sheet: R99P1, Data shape: (63289, 10)
#   Sheet: R99P2, Data shape: (18251, 45)
#   Sheet: R99P3S01, Data shape: (498284, 7)
#   Sheet: R99P3S02, Data shape: (3652, 7)
#   Sheet: R99P3S03, Data shape: (24157, 4)
#   Sheet: R99P3S04, Data shape: (67908, 5)
#   Sheet: R99P3S05, Data shape: (89096, 4)
#   Sheet: R99P3S06, Data shape: (29047, 4)
#   Sheet: R99P3S07, Data shape: (31621, 4)
#   Sheet: R99P3S08, Data shape: (32888, 4)
#   Sheet: R99P3S09, Data shape: (7999, 4)
#   Sheet: R99P3S10, Data shape: (0, 4)
#   Sheet: R99P3S11, Data shape: (6658, 4)
#   Sheet: R99P3S12, Data shape: (64457, 4)
#   Sheet: R99P3S13, Data shape: (183537, 3)
#   Sheet: R99P3S14, Data shape: (4177, 4)
#   Sheet: R99P4S01, Data shape: (10887, 19)
#   Sheet: R99P4S02, Data shape: (12946, 19)
#   Sheet: R99P4S03, Data shape: (23990, 11)
#   Sheet: R99P4S04, Data shape: (29088, 8)
# File: U99
#   Sheet: U99Data, Data shape: (19306, 19)
#   Sheet: R99P1, Data shape: (65666, 10)
#   Sheet: R99P2, Data shape: (19306, 45)
#   Sheet: U99P3S01, Data shape: (603766, 7)
#   Sheet: U99P3S02, Data shape: (3162, 7)
#   Sheet: U99P3S03, Data shape: (29638, 4)
#   Sheet: U99P3S04, Data shape: (83775, 5)
#   Sheet: U99P3S05, Data shape: (99683, 4)
#   Sheet: U99P3S06, Data shape: (33904, 4)
#   Sheet: U99P3S07, Data shape: (37832, 4)
#   Sheet: U99P3S08, Data shape: (41919, 4)
#   Sheet: U99P3S09, Data shape: (9726, 4)
#   Sheet: U99P3S10, Data shape: (0, 4)
#   Sheet: U99P3S11, Data shape: (10161, 4)
#   Sheet: U99P3S12, Data shape: (76547, 4)
#   Sheet: U99P3S13, Data shape: (220481, 3)
#   Sheet: U99P3S14, Data shape: (2783, 4)
#   Sheet: U99P4S01, Data shape: (12186, 19)
#   Sheet: U99P4S02, Data shape: (6377, 19)
#   Sheet: U99P4S03, Data shape: (23632, 11)
#   Sheet: U99P4S04, Data shape: (28520, 8)
# File: R1401
#   Sheet: R1401Data, Data shape: (18384, 15)
#   Sheet: R1401P1, Data shape: (61743, 10)
#   Sheet: R1401P2, Data shape: (18384, 45)
#   Sheet: R1401P3S01, Data shape: (489676, 7)
#   Sheet: R1401P3S02, Data shape: (3652, 7)
#   Sheet: R1401P3S03, Data shape: (22422, 4)
#   Sheet: R1401P3S04, Data shape: (69889, 5)
#   Sheet: R1401P3S05, Data shape: (80751, 4)
#   Sheet: R1401P3S06, Data shape: (28412, 4)
#   Sheet: R1401P3S07, Data shape: (32662, 4)
#   Sheet: R1401P3S08, Data shape: (34789, 4)
#   Sheet: R1401P3S09, Data shape: (10935, 4)
#   Sheet: R1401P3S10, Data shape: (0, 4)
#   Sheet: R1401P3S11, Data shape: (9097, 4)
#   Sheet: R1401P3S12, Data shape: (62506, 4)
#   Sheet: R1401P3S13, Data shape: (174397, 3)
#   Sheet: R1401P3S14, Data shape: (3568, 4)
#   Sheet: R1401P4S01, Data shape: (10303, 19)
#   Sheet: R1401P4S02, Data shape: (11139, 19)
#   Sheet: R1401P4S03, Data shape: (26941, 11)
#   Sheet: R1401P4S04, Data shape: (30755, 8)
# File: U1401
#   Sheet: U1401Data, Data shape: (19567, 15)
#   Sheet: R1401P1, Data shape: (64735, 10)
#   Sheet: R1401P2, Data shape: (19567, 45)
#   Sheet: U1401P3S01, Data shape: (591706, 7)
#   Sheet: U1401P3S02, Data shape: (3110, 7)
#   Sheet: U1401P3S03, Data shape: (25613, 4)
#   Sheet: U1401P3S04, Data shape: (86983, 5)
#   Sheet: U1401P3S05, Data shape: (90303, 4)
#   Sheet: U1401P3S06, Data shape: (30974, 4)
#   Sheet: U1401P3S07, Data shape: (41236, 4)
#   Sheet: U1401P3S08, Data shape: (43267, 4)
#   Sheet: U1401P3S09, Data shape: (12697, 4)
#   Sheet: U1401P3S10, Data shape: (0, 4)
#   Sheet: U1401P3S11, Data shape: (14814, 4)
#   Sheet: U1401P3S12, Data shape: (76382, 4)
#   Sheet: U1401P3S13, Data shape: (212472, 3)
#   Sheet: U1401P3S14, Data shape: (2207, 4)
#   Sheet: U1401P4S01, Data shape: (12312, 19)
#   Sheet: U1401P4S02, Data shape: (6174, 19)
#   Sheet: U1401P4S03, Data shape: (26783, 11)
#   Sheet: U1401P4S04, Data shape: (30772, 8)
# File: R98
#   Sheet: R98Data, Data shape: (18430, 17)
#   Sheet: R98P1, Data shape: (64296, 10)
#   Sheet: R98P2, Data shape: (18430, 45)
#   Sheet: R1399P3S01, Data shape: (516798, 7)
#   Sheet: R1399P3S02, Data shape: (4175, 7)
#   Sheet: R1399P3S03, Data shape: (22378, 4)
#   Sheet: R1399P3S04, Data shape: (68767, 5)
#   Sheet: R1399P3S05, Data shape: (87170, 4)
#   Sheet: R1399P3S06, Data shape: (30600, 4)
#   Sheet: R1399P3S07, Data shape: (35450, 4)
#   Sheet: R1399P3S08, Data shape: (28627, 4)
#   Sheet: R1399P3S09, Data shape: (10839, 4)
#   Sheet: R1399P3S10, Data shape: (0, 4)
#   Sheet: R1399P3S11, Data shape: (11269, 4)
#   Sheet: R1399P3S12, Data shape: (67753, 4)
#   Sheet: R1399P3S13, Data shape: (197127, 3)
#   Sheet: R1399P3S14, Data shape: (4387, 4)
#   Sheet: R1399P4S01, Data shape: (10820, 19)
#   Sheet: R1399P4S02, Data shape: (14339, 19)
#   Sheet: R1399P4S03, Data shape: (18827, 11)
#   Sheet: R1399P4S04, Data shape: (19610, 8)
# File: U98
#   Sheet: U1399Data, Data shape: (19898, 17)
#   Sheet: R1399P1, Data shape: (68245, 10)
#   Sheet: R1399P2, Data shape: (19898, 45)
#   Sheet: U1399P3S01, Data shape: (632359, 7)
#   Sheet: U1399P3S02, Data shape: (3746, 7)
#   Sheet: U1399P3S03, Data shape: (25993, 4)
#   Sheet: U1399P3S04, Data shape: (86250, 5)
#   Sheet: U1399P3S05, Data shape: (96007, 4)
#   Sheet: U1399P3S06, Data shape: (34433, 4)
#   Sheet: U1399P3S07, Data shape: (45388, 4)
#   Sheet: U1399P3S08, Data shape: (38975, 4)
#   Sheet: U1399P3S09, Data shape: (14660, 4)
#   Sheet: U1399P3S10, Data shape: (0, 4)
#   Sheet: U1399P3S11, Data shape: (18480, 4)
#   Sheet: U1399P3S12, Data shape: (81829, 4)
#   Sheet: U1399P3S13, Data shape: (246298, 3)
#   Sheet: U1399P3S14, Data shape: (2952, 4)
#   Sheet: U1399P4S01, Data shape: (12755, 19)
#   Sheet: U1399P4S02, Data shape: (7312, 19)
#   Sheet: U1399P4S03, Data shape: (19137, 11)
#   Sheet: U1399P4S04, Data shape: (19833, 8)

# %%
import copy
data_copy = copy.deepcopy(all_files)

# %%
cost_sheets = ["P3S01", "P3S02", "P3S03", "P3S04", "P3S05", "P3S06", "P3S07",
               "P3S08", "P3S09", "P3S10","P3S11","P3S12","P3S13",]
income_sheets = ["P4S01", "P4S02", "P4S03", "P4S04"]
required_sheets = []
required_sheets.extend(cost_sheets)
required_sheets.extend(income_sheets)
required_sheets
# Out:
# ['P3S01',
#  'P3S02',
#  'P3S03',
#  'P3S04',
#  'P3S05',
#  'P3S06',
#  'P3S07',
#  'P3S08',
#  'P3S09',
#  'P3S10',
#  'P3S11',
#  'P3S12',
#  'P3S13',
#  'P4S01',
#  'P4S02',
#  'P4S03',
#  'P4S04']

# %%
required_dfs = {}
for f, sheets in data_copy.items():
    required_dfs[f] = {}
    for sheet, df in sheets.items():
        for required_sheet in required_sheets:
            if required_sheet in sheet:
                required_dfs[f][required_sheet] = df
                required_dfs[f][required_sheet]["file"] = f

for f, sheets in required_dfs.items():
    for sheet, df in sheets.items():
        print(f)
        # if sheet == "Data":
        print(f"{sheet} : {df.shape}")
        print("-------------------------------------")
# Out:
# R1400
# P3S01 : (509426, 8)
# -------------------------------------
# R1400
# P3S02 : (3621, 8)
# -------------------------------------
# R1400
# P3S03 : (26019, 5)
# -------------------------------------
# R1400
# P3S04 : (69396, 6)
# -------------------------------------
# R1400
# P3S05 : (87768, 5)
# -------------------------------------
# R1400
# P3S06 : (29465, 5)
# -------------------------------------
# R1400
# P3S07 : (32866, 5)
# -------------------------------------
# R1400
# P3S08 : (34928, 5)
# -------------------------------------
# R1400
# P3S09 : (9523, 5)
# -------------------------------------
# R1400
# P3S10 : (0, 5)
# -------------------------------------
# R1400
# P3S11 : (9206, 5)
# -------------------------------------
# R1400
# P3S12 : (66456, 5)
# -------------------------------------
# R1400
# P3S13 : (180585, 4)
# -------------------------------------
# R1400
# P4S01 : (10731, 20)
# -------------------------------------
# R1400
# P4S02 : (12194, 20)
# -------------------------------------
# R1400
# P4S03 : (25097, 12)
# -------------------------------------
# R1400
# P4S04 : (32053, 9)
# -------------------------------------
# U1400
# P3S01 : (617707, 8)
# -------------------------------------
# U1400
# P3S02 : (3207, 8)
# -------------------------------------
# U1400
# P3S03 : (30896, 5)
# -------------------------------------
# U1400
# P3S04 : (85990, 6)
# -------------------------------------
# U1400
# P3S05 : (96497, 5)
# -------------------------------------
# U1400
# P3S06 : (34081, 5)
# -------------------------------------
# U1400
# P3S07 : (40175, 5)
# -------------------------------------
# U1400
# P3S08 : (43990, 5)
# -------------------------------------
# U1400
# P3S09 : (10918, 5)
# -------------------------------------
# U1400
# P3S10 : (0, 5)
# -------------------------------------
# U1400
# P3S11 : (14931, 5)
# -------------------------------------
# U1400
# P3S12 : (80370, 5)
# -------------------------------------
# U1400
# P3S13 : (220419, 4)
# -------------------------------------
# U1400
# P4S01 : (12399, 20)
# -------------------------------------
# U1400
# P4S02 : (6376, 20)
# -------------------------------------
# U1400
# P4S03 : (24345, 12)
# -------------------------------------
# U1400
# P4S04 : (32054, 9)
# -------------------------------------
# R99
# P3S01 : (498284, 8)
# -------------------------------------
# R99
# P3S02 : (3652, 8)
# -------------------------------------
# R99
# P3S03 : (24157, 5)
# -------------------------------------
# R99
# P3S04 : (67908, 6)
# -------------------------------------
# R99
# P3S05 : (89096, 5)
# -------------------------------------
# R99
# P3S06 : (29047, 5)
# -------------------------------------
# R99
# P3S07 : (31621, 5)
# -------------------------------------
# R99
# P3S08 : (32888, 5)
# -------------------------------------
# R99
# P3S09 : (7999, 5)
# -------------------------------------
# R99
# P3S10 : (0, 5)
# -------------------------------------
# R99
# P3S11 : (6658, 5)
# -------------------------------------
# R99
# P3S12 : (64457, 5)
# -------------------------------------
# R99
# P3S13 : (183537, 4)
# -------------------------------------
# R99
# P4S01 : (10887, 20)
# -------------------------------------
# R99
# P4S02 : (12946, 20)
# -------------------------------------
# R99
# P4S03 : (23990, 12)
# -------------------------------------
# R99
# P4S04 : (29088, 9)
# -------------------------------------
# U99
# P3S01 : (603766, 8)
# -------------------------------------
# U99
# P3S02 : (3162, 8)
# -------------------------------------
# U99
# P3S03 : (29638, 5)
# -------------------------------------
# U99
# P3S04 : (83775, 6)
# -------------------------------------
# U99
# P3S05 : (99683, 5)
# -------------------------------------
# U99
# P3S06 : (33904, 5)
# -------------------------------------
# U99
# P3S07 : (37832, 5)
# -------------------------------------
# U99
# P3S08 : (41919, 5)
# -------------------------------------
# U99
# P3S09 : (9726, 5)
# -------------------------------------
# U99
# P3S10 : (0, 5)
# -------------------------------------
# U99
# P3S11 : (10161, 5)
# -------------------------------------
# U99
# P3S12 : (76547, 5)
# -------------------------------------
# U99
# P3S13 : (220481, 4)
# -------------------------------------
# U99
# P4S01 : (12186, 20)
# -------------------------------------
# U99
# P4S02 : (6377, 20)
# -------------------------------------
# U99
# P4S03 : (23632, 12)
# -------------------------------------
# U99
# P4S04 : (28520, 9)
# -------------------------------------
# R1401
# P3S01 : (489676, 8)
# -------------------------------------
# R1401
# P3S02 : (3652, 8)
# -------------------------------------
# R1401
# P3S03 : (22422, 5)
# -------------------------------------
# R1401
# P3S04 : (69889, 6)
# -------------------------------------
# R1401
# P3S05 : (80751, 5)
# -------------------------------------
# R1401
# P3S06 : (28412, 5)
# -------------------------------------
# R1401
# P3S07 : (32662, 5)
# -------------------------------------
# R1401
# P3S08 : (34789, 5)
# -------------------------------------
# R1401
# P3S09 : (10935, 5)
# -------------------------------------
# R1401
# P3S10 : (0, 5)
# -------------------------------------
# R1401
# P3S11 : (9097, 5)
# -------------------------------------
# R1401
# P3S12 : (62506, 5)
# -------------------------------------
# R1401
# P3S13 : (174397, 4)
# -------------------------------------
# R1401
# P4S01 : (10303, 20)
# -------------------------------------
# R1401
# P4S02 : (11139, 20)
# -------------------------------------
# R1401
# P4S03 : (26941, 12)
# -------------------------------------
# R1401
# P4S04 : (30755, 9)
# -------------------------------------
# U1401
# P3S01 : (591706, 8)
# -------------------------------------
# U1401
# P3S02 : (3110, 8)
# -------------------------------------
# U1401
# P3S03 : (25613, 5)
# -------------------------------------
# U1401
# P3S04 : (86983, 6)
# -------------------------------------
# U1401
# P3S05 : (90303, 5)
# -------------------------------------
# U1401
# P3S06 : (30974, 5)
# -------------------------------------
# U1401
# P3S07 : (41236, 5)
# -------------------------------------
# U1401
# P3S08 : (43267, 5)
# -------------------------------------
# U1401
# P3S09 : (12697, 5)
# -------------------------------------
# U1401
# P3S10 : (0, 5)
# -------------------------------------
# U1401
# P3S11 : (14814, 5)
# -------------------------------------
# U1401
# P3S12 : (76382, 5)
# -------------------------------------
# U1401
# P3S13 : (212472, 4)
# -------------------------------------
# U1401
# P4S01 : (12312, 20)
# -------------------------------------
# U1401
# P4S02 : (6174, 20)
# -------------------------------------
# U1401
# P4S03 : (26783, 12)
# -------------------------------------
# U1401
# P4S04 : (30772, 9)
# -------------------------------------
# R98
# P3S01 : (516798, 8)
# -------------------------------------
# R98
# P3S02 : (4175, 8)
# -------------------------------------
# R98
# P3S03 : (22378, 5)
# -------------------------------------
# R98
# P3S04 : (68767, 6)
# -------------------------------------
# R98
# P3S05 : (87170, 5)
# -------------------------------------
# R98
# P3S06 : (30600, 5)
# -------------------------------------
# R98
# P3S07 : (35450, 5)
# -------------------------------------
# R98
# P3S08 : (28627, 5)
# -------------------------------------
# R98
# P3S09 : (10839, 5)
# -------------------------------------
# R98
# P3S10 : (0, 5)
# -------------------------------------
# R98
# P3S11 : (11269, 5)
# -------------------------------------
# R98
# P3S12 : (67753, 5)
# -------------------------------------
# R98
# P3S13 : (197127, 4)
# -------------------------------------
# R98
# P4S01 : (10820, 20)
# -------------------------------------
# R98
# P4S02 : (14339, 20)
# -------------------------------------
# R98
# P4S03 : (18827, 12)
# -------------------------------------
# R98
# P4S04 : (19610, 9)
# -------------------------------------
# U98
# P3S01 : (632359, 8)
# -------------------------------------
# U98
# P3S02 : (3746, 8)
# -------------------------------------
# U98
# P3S03 : (25993, 5)
# -------------------------------------
# U98
# P3S04 : (86250, 6)
# -------------------------------------
# U98
# P3S05 : (96007, 5)
# -------------------------------------
# U98
# P3S06 : (34433, 5)
# -------------------------------------
# U98
# P3S07 : (45388, 5)
# -------------------------------------
# U98
# P3S08 : (38975, 5)
# -------------------------------------
# U98
# P3S09 : (14660, 5)
# -------------------------------------
# U98
# P3S10 : (0, 5)
# -------------------------------------
# U98
# P3S11 : (18480, 5)
# -------------------------------------
# U98
# P3S12 : (81829, 5)
# -------------------------------------
# U98
# P3S13 : (246298, 4)
# -------------------------------------
# U98
# P4S01 : (12755, 20)
# -------------------------------------
# U98
# P4S02 : (7312, 20)
# -------------------------------------
# U98
# P4S03 : (19137, 12)
# -------------------------------------
# U98
# P4S04 : (19833, 9)
# -------------------------------------

# %%
for sheets in required_dfs.values():
    try:
        sheets["P4S01"].drop(
            sheets["P4S01"][
                (sheets["P4S01"]["employed_w"] == 1) &
                (sheets["P4S01"]["income_w_y"] <= 0) &
                (sheets["P4S01"]["netincome_w_y"] <= 0)
            ].index,
            inplace=True,
        )
    except Exception as e:
        print(f"{f} ----> P4S01 ----> {e}")
    try:
        sheets["P4S02"].drop(
            sheets["P4S02"][
                (sheets["P4S02"]["employed_s"] == 1) &
                (sheets["P4S02"]["sale"] <= 0) &
                (sheets["P4S02"]["income_s_y"] <= 0)
            ].index,
            inplace=True,
        )
    except Exception as e:
        print(f"{f} ----> P4S02 ----> {e}")

    try:
        sheets["P4S03"].drop(
            sheets["P4S03"][
                (sheets["P4S03"]["income_pension"] < 0) |
                (sheets["P4S03"]["income_rent"] < 0) |
                (sheets["P4S03"]["income_interest"] < 0) |
                (sheets["P4S03"]["income_resale"] < 0) |
                (sheets["P4S03"]["income_transfer"] < 0)
            ].index,
            inplace=True,
        )
    except Exception as e:
        print(f"{f} ----> P4S03 ----> {e}")
# Out:
# U98 ----> P4S03 ----> '<' not supported between instances of 'str' and 'int'
# U98 ----> P4S03 ----> '<' not supported between instances of 'str' and 'int'
# U98 ----> P4S03 ----> '<' not supported between instances of 'str' and 'int'
# U98 ----> P4S03 ----> '<' not supported between instances of 'str' and 'int'
# U98 ----> P4S02 ----> '<=' not supported between instances of 'str' and 'int'
# U98 ----> P4S02 ----> '<=' not supported between instances of 'str' and 'int'
# U98 ----> P4S03 ----> '<' not supported between instances of 'str' and 'int'
# U98 ----> P4S03 ----> '<' not supported between instances of 'str' and 'int'

# %%
overall_dfs = {}

for f in required_dfs.keys():
    for required_sheet in required_sheets:
        data = overall_dfs.get(required_sheet)
        if data is None:
            overall_dfs[required_sheet] = required_dfs[f][required_sheet]
        else:
            overall_dfs[required_sheet] = pd.concat(
                [overall_dfs[required_sheet], required_dfs[f][required_sheet]],
                axis=0,
            )

# %%
for k in overall_dfs.keys():
    print(f"{k} : {overall_dfs[k].shape}")
# Out:
# P3S01 : (4459722, 8)
# P3S02 : (28325, 8)
# P3S03 : (207116, 5)
# P3S04 : (618958, 6)
# P3S05 : (727275, 5)
# P3S06 : (250916, 5)
# P3S07 : (297230, 5)
# P3S08 : (299383, 5)
# P3S09 : (87297, 5)
# P3S10 : (0, 5)
# P3S11 : (94616, 5)
# P3S12 : (576300, 5)
# P3S13 : (1635316, 4)
# P4S01 : (92252, 20)
# P4S02 : (68086, 20)
# P4S03 : (188752, 12)
# P4S04 : (222685, 9)

# %%
for sheet, df in overall_dfs.items():
    print(f"duplicates of {sheet} : {df[df.duplicated(keep='first')].shape} -----> {df.shape}")
# Out:
# duplicates of P3S01 : (0, 8) -----> (4459722, 8)
# duplicates of P3S02 : (0, 8) -----> (28325, 8)
# duplicates of P3S03 : (0, 5) -----> (207116, 5)
# duplicates of P3S04 : (0, 6) -----> (618958, 6)
# duplicates of P3S05 : (0, 5) -----> (727275, 5)
# duplicates of P3S06 : (0, 5) -----> (250916, 5)
# duplicates of P3S07 : (0, 5) -----> (297230, 5)
# duplicates of P3S08 : (0, 5) -----> (299383, 5)
# duplicates of P3S09 : (0, 5) -----> (87297, 5)
# duplicates of P3S10 : (0, 5) -----> (0, 5)
# duplicates of P3S11 : (0, 5) -----> (94616, 5)
# duplicates of P3S12 : (0, 5) -----> (576300, 5)
# duplicates of P3S13 : (2586, 4) -----> (1635316, 4)
# duplicates of P4S01 : (1, 20) -----> (92252, 20)
# duplicates of P4S02 : (0, 20) -----> (68086, 20)
# duplicates of P4S03 : (0, 12) -----> (188752, 12)
# duplicates of P4S04 : (18, 9) -----> (222685, 9)

# %% [markdown]
# `P3S13`, `P4S01` and `P4S04` has duplicates and as they are low, we can drop them.

# %%
overall_dfs_copy = copy.deepcopy(overall_dfs)

# %%
overall_dfs["P4S04"][overall_dfs["P4S04"].duplicated(keep=False)].head(10)
# Out:
#            Address  member  subsidy_number  subsidy_month    subsidy  Fasl  \
# 14360  22301631723       1             1.0           12.0  1260000.0     2
# 14361  22301631723       1             1.0           12.0  1260000.0     2
# 14097  12301278824       1             1.0           12.0  5460000.0     2
# 14098  12301278824       1             1.0           12.0  5460000.0     2
# 22901  12501305132       1             1.0           12.0  1260000.0     3
# 22902  12501305132       1             1.0           12.0  1260000.0     3
# 30022  12301276227       1             1.0           12.0  5460000.0     4
# 30023  12301276227       1             1.0           12.0  5460000.0     4
# 13665  20404431220       1             NaN           12.0        NaN     3
# 13666  20404431220       1             NaN           12.0        NaN     3
#
#        year  DYCOL00   file
# 14360  1401      NaN  R1400
# 14361  1401      NaN  R1400
# 14097  1401      NaN  U1400
# 14098  1401      NaN  U1400
# 22901  1401      NaN  U1400
# 22902  1401      NaN  U1400
# 30022  1401      NaN  U1400
# 30023  1401      NaN  U1400
# 13665  1399      NaN    R99
# 13666  1399      NaN    R99

# %%
overall_dfs["P4S04"].drop_duplicates(inplace=True)

# %%
overall_dfs["P4S01"][overall_dfs["P4S01"].duplicated(keep=False)]
# Out:
#           Address  member employed_w  ISCO_w   ISIC_w status_w hours_w days_w  \
# 5452  20005389220       3          2  9314.0  41000.0        3     NaN    NaN
# 5453  20005389220       3          2  9314.0  41000.0        3     NaN    NaN
#
#       income_w_m  income_w_y  wage_w_m    wage_w_y  perk_w_m  perk_w_y  \
# 5452           0    40000000       0.0  40000000.0       0.0       0.0
# 5453           0    40000000       0.0  40000000.0       0.0       0.0
#
#       netincome_w_m  netincome_w_y  Fasl  year  DYCOL00 file
# 5452              0       40000000     3  1399      NaN  R99
# 5453              0       40000000     3  1399      NaN  R99

# %%
overall_dfs["P4S01"].drop_duplicates(inplace=True)

# %%
overall_dfs["P3S13"][overall_dfs["P3S13"].duplicated(keep=False)].head(10)
# Out:
#           Address    code       value   file
# 2733  20111403626  125111  0000285000  R1400
# 2734  20111403626  125111  0000285000  R1400
# 2891  20106401035  125111  0000285000  R1400
# 2892  20106401035  125111  0000285000  R1400
# 2908  20107401527  125111  0000285000  R1400
# 2909  20107401527  125111  0000285000  R1400
# 3004  20108401935  125111  0000285000  R1400
# 3005  20108401935  125111  0000285000  R1400
# 3134  20106401023  125111  0000285000  R1400
# 3135  20106401023  125111  0000285000  R1400

# %%
overall_dfs["P3S13"].drop_duplicates(inplace=True)

# %%
for sheet, df in overall_dfs.items():
    print(f"duplicates of {sheet} : {df[df.duplicated(keep='first')].shape} -----> {df.shape}")
# Out:
# duplicates of P3S01 : (0, 8) -----> (4459722, 8)
# duplicates of P3S02 : (0, 8) -----> (28325, 8)
# duplicates of P3S03 : (0, 5) -----> (207116, 5)
# duplicates of P3S04 : (0, 6) -----> (618958, 6)
# duplicates of P3S05 : (0, 5) -----> (727275, 5)
# duplicates of P3S06 : (0, 5) -----> (250916, 5)
# duplicates of P3S07 : (0, 5) -----> (297230, 5)
# duplicates of P3S08 : (0, 5) -----> (299383, 5)
# duplicates of P3S09 : (0, 5) -----> (87297, 5)
# duplicates of P3S10 : (0, 5) -----> (0, 5)
# duplicates of P3S11 : (0, 5) -----> (94616, 5)
# duplicates of P3S12 : (0, 5) -----> (576300, 5)
# duplicates of P3S13 : (0, 4) -----> (1632730, 4)
# duplicates of P4S01 : (0, 20) -----> (92251, 20)
# duplicates of P4S02 : (0, 20) -----> (68086, 20)
# duplicates of P4S03 : (0, 12) -----> (188752, 12)
# duplicates of P4S04 : (0, 9) -----> (222667, 9)

# %%
overall_dfs["P4S04"].head()
# Out:
#        Address  member  subsidy_number  subsidy_month     subsidy  Fasl  year  \
# 0  20001384225       1             1.0           12.0   1960000.0     1  1401
# 1  20001384225       2             2.0           12.0  10920000.0     1  1401
# 2  20001384232       1             1.0           12.0   1960000.0     1  1401
# 3  20001384232       2             2.0           12.0  10920000.0     1  1401
# 4  20001384235       1             1.0           12.0   1960000.0     1  1401
#
#    DYCOL00   file
# 0      NaN  R1400
# 1      NaN  R1400
# 2      NaN  R1400
# 3      NaN  R1400
# 4      NaN  R1400

# %%
required_features = {
    "P3S" : ["address", "value", "file"],
    "P3S04" : ["address", "mortgage", "value", "file"],
    "P3S13" : ["address", "value", "file"],
    "P4S01" : ["address", "netincome_w_y", "file"],
    "P4S02" : ["address", "income_s_y", "file"],
    "P4S03" : ["address", "income_pension", "income_rent",
               "income_interest", "income_aid", "income_resale",
               "income_transfer", "file"],
    "P4S04" : ["address", "subsidy", "file"],
}

# %%
for sheet, df in overall_dfs.items():
    df.columns = df.columns.str.lower()

    if sheet.startswith("P3S") and sheet != "P3S04" and sheet != "P3S13":
        overall_dfs[sheet] = overall_dfs[sheet][required_features["P3S"]]
        numeric_cols = [col for col in required_features["P3S"] if col not in ["address", "file"]]
    else:
        overall_dfs[sheet] = overall_dfs[sheet][required_features[sheet]]
        numeric_cols = [col for col in required_features[sheet] if col not in ["address", "file"]]

    overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
    if sheet.startswith("P3S"):
        overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
    elif sheet == "P4S04":
        pass
    elif sheet.startswith("P4S"):
        overall_dfs[sheet]["income"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# Out:
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["cost"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["income"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["income"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")
# <ipython-input-23-7888a2f7bfbc>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet]["income"] = overall_dfs[sheet][numeric_cols].sum(axis=1)
# <ipython-input-23-7888a2f7bfbc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   overall_dfs[sheet][numeric_cols] = overall_dfs[sheet][numeric_cols].apply(pd.to_numeric, errors="coerce")

# %%
overall_dfs["P4S01"][overall_dfs["P4S01"]["netincome_w_y"] <= 0]
# Out:
#            address  netincome_w_y   file  income
# 1282   11401173035              0  U1401       0
# 1283   11401173035              0  U1401       0
# 1284   11401173429              0  U1401       0
# 1285   11401173435              0  U1401       0
# 1319   11402176638              0  U1401       0
# 1377   11408182226              0  U1401       0
# 1804   11907227838              0  U1401       0
# 2166   12301267135              0  U1401       0
# 2268   12301278338              0  U1401       0
# 4130   11104138441              0  U1401       0
# 4294   11302159429              0  U1401       0
# 5343   12301273731              0  U1401       0
# 5384   12301276930              0  U1401       0
# 7003   11904226538              0  U1401       0
# 7498   12301279038              0  U1401       0
# 7547   12303286238              0  U1401       0
# 10582  11402175135              0  U1401       0
# 11466  12301273632              0  U1401       0
# 11487  12301276025              0  U1401       0
# 11978  12706336132              0  U1401       0
# 9517   21406551014              0    R98       0
# 4727   11402176317              0    U98       0
# 4728   11402176317              0    U98       0
# 4729   11402176317              0    U98       0
# 4730   11402176317              0    U98       0
# 4731   11402176317              0    U98       0

# %%
costs = []
incomes = []
# subsid_df = overall_dfs.pop("P4S04")
for sheet, df in overall_dfs.items():
    if sheet.startswith("P3S"):
        costs.append(df[["address", "cost", "file"]])
    elif sheet == "P4S04":
        subsids_df = df.copy()
    elif sheet.startswith("P4S"):
        incomes.append(df[["address", "income", "file"]])

costs_df = pd.concat(costs).groupby(["address", "file"], as_index=False).sum("cost")
incomes_df = pd.concat(incomes).groupby(["address", "file"], as_index=False).sum("income")

# %%
costs_df.head(10)
# Out:
#        address   file         cost
# 0  10001000108    U98  152193000.0
# 1  10001000111    U98  208140288.0
# 2  10001000113    U99  243967000.0
# 3  10001000114    U98   43402000.0
# 4  10001000116    U99  314822000.0
# 5  10001000117    U98   89418000.0
# 6  10001000119  U1400  192519000.0
# 7  10001000120  U1400  847235000.0
# 8  10001000120    U98   59097000.0
# 9  10001000120    U99  289044000.0

# %%
incomes_df.head(10)
# Out:
#        address   file        income
# 0  10001000108    U98  3.920000e+08
# 1  10001000111    U98  5.640000e+08
# 2  10001000113    U99  8.880000e+08
# 3  10001000114    U98  1.440000e+08
# 4  10001000116    U99  6.540000e+08
# 5  10001000117    U98  4.440000e+08
# 6  10001000119  U1400  9.055000e+08
# 7  10001000120  U1400  1.373500e+09
# 8  10001000120    U98  3.330000e+08
# 9  10001000120    U99  9.760000e+08

# %%
subsids_df.head(10)
# Out:
#        address     subsidy   file
# 0  20001384225   1960000.0  R1400
# 1  20001384225  10920000.0  R1400
# 2  20001384232   1960000.0  R1400
# 3  20001384232  10920000.0  R1400
# 4  20001384235   1960000.0  R1400
# 5  20001384235   5460000.0  R1400
# 6  20011394620   1610000.0  R1400
# 7  20011394620  16380000.0  R1400
# 8  20011394623   1610000.0  R1400
# 9  20011394623  10920000.0  R1400

# %%
final_df = pd.merge(costs_df, incomes_df, on=["address", "file"])
final_df_with_subsid = pd.merge(final_df, subsids_df, on=["address", "file"])

# %%
final_df.head()
# Out:
#        address file         cost       income
# 0  10001000108  U98  152193000.0  392000000.0
# 1  10001000111  U98  208140288.0  564000000.0
# 2  10001000113  U99  243967000.0  888000000.0
# 3  10001000114  U98   43402000.0  144000000.0
# 4  10001000116  U99  314822000.0  654000000.0

# %%
# final_df["sub"] = final_df["income"] - final_df["cost"]

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(final_df[["cost", "income"]])

# %%
kmeans = KMeans(n_clusters=10, random_state=42)
kmeans.fit(x_scaled)
labels = kmeans.labels_
final_df["label"] = labels
centers = kmeans.cluster_centers_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
